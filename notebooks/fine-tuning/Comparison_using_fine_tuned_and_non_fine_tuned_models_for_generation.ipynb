# %%
#Check the GPU information
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Jul 29 10:12:26 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   42C    P8              12W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
#checking GPU resources, specifically memory
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 56.9 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# ### Installing Required Libraries
#
# First, we will install some required libraries.
#
# `transformers`: for loading a large language model and fine-tuning it.
#
# `bitsandbytes`: for loading the model in 4-bit precision.
#
# `accelerate`: for training models and performing inference at scale.
#
# `peft`: for fine-tuning a small number of parameters.
#
# `trl`: for training transformer language models using Reinforcement Learning.

# %%
# !pip install -q accelerate==0.21.0 --progress-bar off
# !pip install -q peft==0.4.0 --progress-bar off
# !pip install -q bitsandbytes==0.40.2 --progress-bar off
# !pip install -q transformers==4.31.0 --progress-bar off
# !pip install -q trl==0.4.7 --progress-bar off
# !pip install xformers
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.5.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Collecting xformers
#   Downloading xformers-0.0.27.post2-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xformers) (1.25.2)
# Collecting torch==2.4.0 (from xformers)
#   Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (12.1.105)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.4.0->xformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->xformers) (12.1.105)
# Collecting triton==3.0.0 (from torch==2.4.0->xformers)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.0->xformers) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.4.0->xformers) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.4.0->xformers) (1.3.0)
# Downloading xformers-0.0.27.post2-cp310-cp310-manylinux2014_x86_64.whl (20.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 89.5 MB/s eta 0:00:00
# Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 4.1 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-cudnn-cu12, torch, xformers
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.1
#     Uninstalling triton-2.3.1:
#       Successfully uninstalled triton-2.3.1
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 8.9.2.26
#     Uninstalling nvidia-cudnn-cu12-8.9.2.26:
#       Successfully uninstalled nvidia-cudnn-cu12-8.9.2.26
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1+cu121
#     Uninstalling torch-2.3.1+cu121:
#       Successfully uninstalled torch-2.3.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.15 requires torch<2.4,>=1.10, but you have torch 2.4.0 which is incompatible.
# torchaudio 2.3.1+cu121 requires torch==2.3.1, but you have torch 2.4.0 which is incompatible.
# torchvision 0.18.1+cu121 requires torch==2.3.1, but you have torch 2.4.0 which is incompatible.
# Successfully installed nvidia-cudnn-cu12-9.1.0.70 torch-2.4.0 triton-3.0.0 xformers-0.0.27.post2

# %% [markdown]
# ### Loading Required Libraries
#
# Next, we will load the required libraries for fine-tuning a Large Language Model (LLM) (like Llama 2).

# %%
import os
from random import randrange
from functools import partial
import torch
from datasets import load_dataset
from transformers import (AutoModelForCausalLM,
                          AutoTokenizer,
                          BitsAndBytesConfig,
                          HfArgumentParser,
                          Trainer,
                          EarlyStoppingCallback,
                          TrainingArguments,
                          DataCollatorForLanguageModeling,
                          EarlyStoppingCallback,
                          pipeline,
                          logging,
                          set_seed)

import bitsandbytes as bnb
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training, PeftModel, AutoPeftModelForCausalLM
from trl import SFTTrainer
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Hugging Face Hub Login

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: fineGrained).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Fine-tuned model name on Hugging Face Hub
model_id = "jonikyud/fairytale-generation-llama2_cf_full"
input_parameters="/content/drive/MyDrive/fairytale_testing.csv"
csv_file_name ="/content/drive/MyDrive/llama2_finetuned_full.csv"

# %%
from transformers import pipeline

# Load the text generation pipeline
generator = pipeline("text-generation", model=model_id, tokenizer=model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:460: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/676 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/xformers/ops/fmha/flash.py:211: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_fwd")
# /usr/local/lib/python3.10/dist-packages/xformers/ops/fmha/flash.py:344: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_bwd")

# %%
# open input parameters csv file
# iterate over the parameters and for each parameter generate output story
import pandas as pd
dataframe = pd.read_csv(input_parameters)
df = pd.DataFrame()
for index, row in dataframe.iterrows():
    parameters_value = row['generated_key']
    prompt= f"{parameters_value}->"
    print(prompt)
    # Generate text
    generated_text = generator(prompt, max_length=500, num_return_sequences=1)[0]['generated_text']
    print(generated_text)
    new_row = {
            'parameters':parameters_value,
            'text':generated_text,
            }
    new_row = pd.DataFrame([new_row])
    df = pd.concat([df, new_row], axis=0, ignore_index=True)


# Print the generated text
df
# Out:
# Aquilan the Mistweaver, Glimmering Galaxies, stardust betrayal->
# Aquilan the Mistweaver, Glimmering Galaxies, stardust betrayal->In the enchanting land of Glimmering Galaxies, there lived a wise and powerful sorceress named Aquilan the Mistweaver.
# Aquilan was known throughout the land for her mastery of the ancient art of mistweaving, which allowed her to manipulate the very fabric of reality itself. With her shimmering silver hair and eyes that shone like the stars, she was a sight to behold.
# One day, Aquilan received a message from the wise old owl, who warned her of a great betrayal that threatened to destroy the balance of the universe. The stardust, which held the power of creation, had been stolen by a dark and malevolent force.
# Determined to restore balance and protect the universe, Aquilan embarked on a perilous journey through the Glimmering Galaxies. Along the way, she encountered magical creatures and overcame treacherous obstacles, all while unraveling the mysteries of the stardust betrayal.
# With her cunning and her mastery of mistweaving, Aquilan was able to defeat the dark force and restore the stardust to its rightful place. The universe was saved, and Aquilan emerged as a hero, her legend forever etched in the annals of time.
# MoonChild, Realm of Dreams, Quest to find the Lost Mirror Piece->
# MoonChild, Realm of Dreams, Quest to find the Lost Mirror Piece->In the mystical Realm of Dreams, the MoonChild embarked on a quest to find the Lost Mirror Piece.
# With her shimmering silver hair and glowing moonstone eyes, the MoonChild possessed the power to control the dreams of all who slept. But when the Lost Mirror Piece was stolen, the balance of dreams was disrupted, and the MoonChild knew she must embark on a perilous journey to retrieve it.
# Through treacherous forests and treacherous mountains, the MoonChild braved the unknown, facing fierce creatures and solving enigmatic riddles. With her quick wit and unwavering determination, she finally reached the dark castle where the Lost Mirror Piece was hidden.
# With a final burst of magic, the MoonChild defeated the evil sorcerer guarding the castle and claimed the Lost Mirror Piece. With its power, she restored balance to the dreams of all, and the Realm of Dreams was once again filled with peace and tranquility.
# The MoonChild returned home, her silver hair shimmering with the light of her triumph, and her glowing moonstone eyes filled with the wisdom of her journey. For in the Realm of Dreams, the MoonChild knew that the power of magic and determination could overcome even the darkest of challenges.
# Amoon Oakhaven, Enchanted Forest of Lumn, Tapping into the Magic->
# Amoon Oakhaven, Enchanted Forest of Lumn, Tapping into the Magic->In the Enchanted Forest of Lumn, there lived a magical creature known as the Amoon Oakhaven.
# Amoon was a majestic being with shimmering silver scales, iridescent wings, and a flowing mane of emerald green hair. She possessed the power to control the elements, summoning the wind, rainbows, and the whispers of ancient trees.
# One day, Amoon received a message from the wise old trees of the forest, calling upon her to embark on a quest to tap into the magic of the Enchanted Forest. The trees had sensed a growing darkness threatening the balance of nature, and they believed that Amoon held the key to restoring harmony.
# With determination in her heart, Amoon set off on her journey, facing treacherous paths, solving riddles, and battling fierce creatures. Along the way, she discovered hidden secrets and unlocked ancient powers, unleashing a wave of magic that echoed through the forest.
# As she reached the heart of the Enchanted Forest, Amoon encountered the source of the darkness: a powerful sorcerer who had sought to exploit the forest's magic for his own gain. With her powers combined, Amoon defeated the sorcerer and restored balance to the forest, ensuring that the magic of Lumn would forever thrive.
# With her mission accomplished, Amoon returned to her home in the Oakhaven, her legend growing as a guardian of the Enchanted Forest, and her legacy as a symbol of hope and magic lived on forever.
# Enigma, Neverland, saving the lost memories->
# Enigma, Neverland, saving the lost memories->In the mystical land of Neverland, there lived a magical creature known as the Enigma.
# The Enigma had the power to control time and space, and it was said that it could grant wishes to those who possessed the purest of intentions. One day, a young adventurer named Lily stumbled upon the Enigma, lost in the depths of the forest.
# Lily, with her golden hair and sparkling eyes, was on a quest to save the lost memories of Neverland. She had heard whispers of a dark force that threatened to erase the memories of the land, and she knew that she had to stop it.
# With the Enigma's help, Lily embarked on a journey through time and space, facing challenges and obstacles along the way. She encountered mythical creatures, solved riddles, and uncovered hidden secrets.
# As she journeyed deeper into the heart of the forest, Lily discovered that the dark force was none other than the Shadow, a powerful and malevolent being that sought to destroy the memories of Neverland.
# With the Enigma's guidance, Lily used her courage and determination to defeat the Shadow and restore the lost memories of Neverland. And as she did, the land was filled with light and magic once again, and the Enigma disappeared, its work done.
# From that day on, Lily became known as the savior of Neverland, and her legend lived on for generations to come. And the Enigma, the mysterious and powerful guardian of time and space, remained a secret, waiting for the next adventurer to come along and continue its work.
# Lumina, Underwater Kingdom, Finding the Lost Pearl->
# Lumina, Underwater Kingdom, Finding the Lost Pearl->In the enchanting Underwater Kingdom, Lumina, a magical mermaid, embarked on a thrilling adventure to find the Lost Pearl.
# With her shimmering scales and flowing golden hair, Lumina swam through the crystal-clear waters, facing treacherous sea creatures and solving riddles along the way.
# As she journeyed deeper into the depths of the ocean, she discovered hidden caves and secret gardens, filled with exotic seaweed and sparkling jewels.
# Finally, after overcoming countless challenges, Lumina found the Lost Pearl, a radiant gem that glowed with an ethereal light. With its power, she could grant wishes to all the creatures of the Underwater Kingdom, bringing joy and harmony to the magical realm.
# With her heart full of wonder and her spirit soaring, Lumina returned home, her legendary adventure forever etched in the annals of the Underwater Kingdom's history.
# Moonbeam, Nebulosa, The enchanted prism->
# Moonbeam, Nebulosa, The enchanted prism->In the mystical land of Nebulosa, there lived a magical creature known as the Moonbeam.
# The Moonbeam was a shimmering, iridescent creature with the power to control the moon's light. With its ethereal beauty and magical abilities, the Moonbeam was revered by all who lived in Nebulosa.
# One day, a dark force threatened to destroy the land, and the Moonbeam was called upon to save it. With its enchanted prism, the Moonbeam embarked on a perilous journey to defeat the darkness and restore peace to Nebulosa.
# Along the way, the Moonbeam encountered fierce creatures and overcame treacherous obstacles, but its determination and magical powers ultimately prevailed. With the darkness vanquished and peace restored, the Moonbeam became a legendary hero in the land of Nebulosa.
# The story of the Moonbeam serves as a reminder that even in the darkest of times, there is always hope and the power to overcome any challenge. Its legacy lives on, inspiring future generations to embrace their own magical abilities and protect the enchanted land of Nebulosa.
# Stellar Eclipse, Celest Earth Haven, Mind Games->
# Stellar Eclipse, Celest Earth Haven, Mind Games->In the mystical land of Celest Earth Haven, the enchanting Stellar Eclipse embarked on a thrilling adventure.
# With her shimmering silver hair and piercing emerald eyes, Stellar was known for her unparalleled magical abilities. One day, she received a cryptic message from the wise Celestial Oracle, warning her of an impending danger threatening the balance of the universe.
# Determined to save the realm, Stellar embarked on a perilous journey through treacherous landscapes and treacherous creatures. With her quick wit and unwavering courage, she unraveled complex riddles and uncovered hidden secrets.
# As she navigated through the challenges, Stellar discovered that the true threat was not from a dark sorcerer or a powerful demon, but from a sinister force within her own mind. With the fate of the universe hanging in the balance, Stellar must confront her inner demons and unlock the true power of her magical abilities.
# In the end, Stellar emerged victorious, restoring balance to the universe and solidifying her place as the most powerful sorceress in Celest Earth Haven. With her legendary exploits, she inspired generations of magical creatures to embrace their unique abilities and protect the realm from any danger that may arise.
# Luminia, Enchanted Forest, finding the golden key->
# Luminia, Enchanted Forest, finding the golden key->In the mystical land of Luminia, deep within the Enchanted Forest, there lived a magical creature named Lily.
# One day, Lily embarked on a quest to find the legendary golden key, said to possess the power to unlock the secrets of the forest. With her shimmering silver wings and enchanted crystal eyes, Lily braved treacherous paths and encountered mischievous creatures, but she never gave up.
# After many trials and tribulations, Lily finally found the golden key hidden in a secret grove guarded by ancient trees. With the key in hand, she unlocked the mysteries of the forest, revealing hidden treasures and unlocking the secrets of the magical creatures that lived there.
# With her bravery and determination, Lily became a legendary hero in the land of Luminia, and her name was whispered in awe and reverence throughout the Enchanted Forest.
# Merlin, floating islands of Zumaria, search of ancient wisdom scrolls->
# Merlin, floating islands of Zumaria, search of ancient wisdom scrolls->In the mystical land of Zumaria, there lived a legendary magician named Merlin.
# One day, Merlin embarked on a quest to find the ancient wisdom scrolls hidden deep within the floating islands of Zumaria. With his trusty wand and enchanted cloak, Merlin braved treacherous storms and navigated through treacherous mazes to reach the hidden islands.
# As he journeyed through the islands, Merlin encountered magical creatures and solved riddles to unlock the secrets of the ancient scrolls. With each scroll he found, Merlin gained more wisdom and power, and his legend grew throughout Zumaria.
# In the end, Merlin returned to his home, the enchanted forest of Zumaria, with the ancient wisdom scrolls in hand, and his legendary status as the greatest magician of all time was cemented forever.
# The story of Merlin's quest for the ancient wisdom scrolls became a legendary tale told for generations to come, inspiring young magicians and adventurers to embark on their own quests for knowledge and power.
# Luna Star, Rainbow Valley, The Emerald Multi-Puzzle Quest->
# Luna Star, Rainbow Valley, The Emerald Multi-Puzzle Quest->In the enchanting land of Rainbow Valley, there lived a magical creature named Luna Star.
# Luna Star was a shimmering, iridescent unicorn with a flowing mane of silver and gold. She possessed the power to control the elements, and her wisdom was unmatched in all of Rainbow Valley.
# One day, a mysterious riddle appeared in the heart of Rainbow Valley, and it was said that only Luna Star could solve it. The riddle was known as the Emerald Multi-Puzzle Quest, and it was guarded by ancient, magical creatures.
# With determination and grace, Luna Star embarked on a thrilling adventure to unravel the riddle. Along the way, she encountered mischievous fairies, wise owls, and even a mischievous dragon. But with her quick wit and unwavering courage, she overcame every obstacle and finally solved the riddle.
# As a reward, the magical creatures of Rainbow Valley gifted Luna Star with a magical crystal that granted her the power to control time itself. With her newfound power, she continued to protect and guide Rainbow Valley, ensuring that its beauty and magic remained untainted forever.
# And so, Luna Star became known as the greatest hero of Rainbow Valley, and her legend lived on for generations to come.
# The Sparkling Sorceress, Glimmergia, The Quest for the Shimmering Crystal->
# The Sparkling Sorceress, Glimmergia, The Quest for the Shimmering Crystal->In the enchanting land of Glimmergia, there lived a magical sorceress named Sparkle.
# Sparkle was known throughout the land for her shimmering silver hair and her ability to control the elements. One day, she received a message from the wise old wizard, Wysteria, who lived deep in the heart of the mystical forest. Wysteria had discovered a powerful crystal hidden deep within the forest, known as the Shimmering Crystal. The crystal had the power to grant wishes and bring peace to the land.
# Sparkle embarked on a perilous journey to find the Shimmering Crystal. Along the way, she encountered fierce creatures and overcame treacherous obstacles. But with her quick wit and magical powers, she was able to overcome every challenge.
# Finally, Sparkle reached the heart of the forest and found the Shimmering Crystal. With a gentle touch, she granted her heart's deepest wish, bringing peace and prosperity to the land of Glimmergia. And so, Sparkle became known as the Sparkling Sorceress, the protector of the land and the guardian of the Shimmering Crystal.
# Dreamlark, Aquarelia, The Quest for the Everlasting Fountain->
# Dreamlark, Aquarelia, The Quest for the Everlasting Fountain->In the enchanting land of Aquarelia, there lived a magical creature known as the Dreamlark.
# With shimmering feathers of iridescent blue and eyes that shone like the stars, the Dreamlark possessed the power to control the dreams of all who encountered it. It was said that the Dreamlark could grant wishes and solve problems with its magical melodies, and many creatures sought its help in times of need.
# One day, a young and adventurous creature named Aqua, who lived in the mystical forest of Aquarelia, heard of the legendary Everlasting Fountain hidden deep within the forest. The fountain was said to grant eternal youth and vitality to those who drank from its waters, and Aqua was determined to find it.
# With the guidance of the wise old owl, Aqua embarked on a perilous journey through treacherous mountains and dark caves, facing fierce creatures and solving riddles along the way. Finally, after many trials and tribulations, Aqua reached the Everlasting Fountain, where the Dreamlark awaited.
# With a melody so pure and enchanting, the Dreamlark granted Aqua the power to drink from the fountain, and the young creature was transformed into a radiant being with the power to control the elements themselves. With its newfound powers, Aqua returned to Aquarelia, bringing peace and prosperity to all creatures in the land. And so, the legend of the Dreamlark and the Everlasting Fountain lived on, inspiring generations of creatures to seek out their dreams and unlock their true potential.
# Merien, Enchanted Forest, Finding the Lost Book->
# Merien, Enchanted Forest, Finding the Lost Book->In the mystical Enchanted Forest, there lived a magical creature named Merien.
# Merien was a wise and kind creature with shimmering silver scales and emerald green eyes. She had long, flowing silver hair that sparkled like diamonds in the moonlight.
# One day, Merien received a message from the ancient wise owl, who lived deep within the Enchanted Forest. The owl told Merien that a lost book, filled with ancient spells and secrets, had been stolen from the sacred library of the forest.
# Determined to find the lost book, Merien embarked on a perilous journey through treacherous mountains and dark caves. Along the way, she encountered fierce creatures and overcame challenging obstacles.
# Finally, after many days of searching, Merien found the lost book hidden deep within a hidden cave. With the book in her possession, Merien returned to the Enchanted Forest, where she shared the ancient spells and secrets with all who lived there.
# Thanks to Merien's bravery and determination, the Enchanted Forest was once again filled with magic and wonder. And Merien lived happily ever after, surrounded by the creatures and plants she had protected and cherished.
# Luna Whisperwind, Celestial Spire, aurora pearls and the moon's melody->
# Luna Whisperwind, Celestial Spire, aurora pearls and the moon's melody->In the mystical land of Celestial Spire, there lived a magical creature known as Luna Whisperwind.
# Luna was a beautiful, iridescent unicorn with a flowing mane of silver and gold. She possessed the power to control the aurora pearls, which glowed with a mesmerizing light that could heal the sick and bring peace to the troubled.
# One day, Luna embarked on a quest to find the lost melody of the moon. She traveled through enchanted forests, crossed sparkling rivers, and climbed towering mountains. Along the way, she encountered magical creatures and solved riddles that led her closer to her goal.
# Finally, Luna reached the moon's chamber, where she discovered the lost melody. With her magic, she sang the melody back to life, filling the land with a radiant light that brought joy and harmony to all.
# From that day on, Luna became known as the guardian of the aurora pearls and the moon's melody, using her powers to maintain peace and balance in the mystical land of Celestial Spire.
# Lumiya, Enchanted Forest, stranded with no magic->
# Lumiya, Enchanted Forest, stranded with no magic->In the Enchanted Forest, Lumiya, a magical unicorn, was on a quest to find the lost magic crystal.
# One day, while exploring the forest, Lumiya stumbled upon a mysterious portal. Without hesitation, she stepped through the portal and found herself in a strange and unfamiliar land.
# With no magic to guide her, Lumiya must use her wit and determination to survive and find her way back home. Along the way, she meets new friends and faces challenges that test her courage and resilience. Will she be able to find the lost magic crystal and restore the magic to the Enchanted Forest? Or will she remain stranded in this strange land forever?
# Join Lumiya on her thrilling adventure as she embarks on a quest to reclaim her magic and save the Enchanted Forest from darkness. With her shimmering coat and sparkling horn, Lumiya is ready to face any challenge that comes her way. Will you join her on this magical journey?
# Mysti the Mermaid, Solaraya, Saving the Crystal Kingdom->
# Mysti the Mermaid, Solaraya, Saving the Crystal Kingdom->In the enchanting land of Crystal Kingdom, there lived a magical creature named Mysti the Mermaid.
# Mysti was known for her shimmering scales that glimmered in the sunlight, and her long flowing hair that resembled the waves of the ocean. She possessed the power to control the elements, and her kind heart made her a beloved figure in the kingdom.
# One day, the Crystal Kingdom was threatened by an evil sorcerer who sought to destroy the magical crystals that kept the kingdom alive. Mysti knew she had to act fast to save her home and embarked on a perilous journey to find the lost crystal of light.
# With her powers, Mysti navigated through treacherous waters, braved dark caves, and outsmarted fierce creatures to reach the heart of the crystal. With her final breath, she restored the crystal's shine and saved the Crystal Kingdom from destruction.
# The kingdom celebrated Mysti's bravery, and her legend grew as a hero who protected the land with her magical powers. Mysti continued to watch over the kingdom, ensuring peace and harmony reigned for generations to come.
# Starrish, Enchanted Forest, saving the moon elves lover->
# Starrish, Enchanted Forest, saving the moon elves lover->In the Enchanted Forest, there lived a magical creature known as the Starlight Starrish.
# One day, the moon elves, who lived in the highest reaches of the forest, were threatened by a dark force that sought to destroy their home. The Starlight Starrish, with its shimmering silver wings and glowing emerald eyes, embarked on a quest to save the moon elves and their enchanted forest.
# With its powers of telekinesis and the ability to control the elements, the Starlight Starrish battled fierce creatures and overcame treacherous obstacles. Along the way, it discovered hidden secrets and unlocked ancient magic, leading it to the heart of the dark force.
# In a final showdown, the Starlight Starrish faced off against the dark force, using all of its powers to defeat it and save the moon elves. With the forest safe once again, the Starlight Starrish returned home, hailed as a hero by all who lived in the Enchanted Forest.
# The Starlight Starrish had saved the day, and its legend would live on forever, inspiring future generations to protect the magical creatures and enchanted lands of the Enchanted Forest.
# Starlight Maiden, Enchanted Forest, The Wandering Crown->
# Starlight Maiden, Enchanted Forest, The Wandering Crown->In the Enchanted Forest, there lived a magical creature known as the Starlight Maiden.
# One day, while wandering through the forest, she stumbled upon a mysterious crown. As soon as she touched it, she felt an incredible power coursing through her veins.
# With her newfound abilities, she set out on a quest to find the lost treasures of the forest. Along the way, she encountered fierce creatures and overcame challenging obstacles, but with her bravery and determination, she emerged victorious.
# As she returned to her home, she realized that the crown had given her the power to control the stars themselves. With her newfound powers, she vowed to protect the Enchanted Forest and all its magical creatures, ensuring that the magic of the forest would never fade away.
# In this enchanting tale, the Starlight Maiden embarks on a thrilling adventure, discovering hidden treasures and unlocking her true potential. With her bravery and determination, she becomes a legendary hero, forever changing the fate of the Enchanted Forest.
# Astrollox, Enchanted Forest of Whispers, The Gravity Gauntlet->
# Astrollox, Enchanted Forest of Whispers, The Gravity Gauntlet->In the Enchanted Forest of Whispers, there lived a magical creature known as Astrollox.
# Astrollox was a majestic creature with shimmering silver scales, iridescent wings, and a long, flowing mane of golden hair. With its enchanted powers, Astrollox could control the elements, summoning powerful storms and conjuring illusions that could deceive even the wisest of creatures.
# One day, Astrollox stumbled upon a mysterious artifact known as the Gravity Gauntlet. This ancient relic had the power to manipulate the very fabric of reality, bending time and space to the will of its wearer.
# Astrollox knew that the Gravity Gauntlet was too powerful for any one creature to possess, so it vowed to protect it from falling into the wrong hands. But as fate would have it, the Gauntlet was stolen by a dark sorcerer who sought to use its power for evil purposes.
# Determined to stop the sorcerer, Astrollox embarked on a perilous quest to retrieve the Gravity Gauntlet. Along the way, it encountered treacherous landscapes, ferocious creatures, and even betrayal from those it trusted most. But with its unwavering courage and unparalleled magical abilities, Astrollox emerged victorious, restoring balance to the Enchanted Forest of Whispers and ensuring that the Gravity Gauntlet remained safe from harm.
# Alcidalisus Grimbletone, Orion Gonzoshine, Theophania Fireblaze->
# Alcidalisus Grimbletone, Orion Gonzoshine, Theophania Fireblaze->In the mystical land of Aloria, where the sun dipped into the horizon and painted the sky with hues of crimson and gold, there lived a wise and powerful sorceress named Orion Gonzoshine.
# Orion was known throughout the land for her mastery of the ancient art of magic, and her unwavering dedication to protecting the innocent and vanquishing evil. With her long silver hair cascading down her back like a river of moonlight, and her eyes shining like the stars in the night sky, she was a sight to behold.
# One day, a dark and ominous shadow descended upon the land, threatening to destroy everything that was good and pure. The shadow was known as the Alcidalisus Grimbletone, a powerful and malevolent sorcerer who sought to rule over all of Aloria with an iron fist.
# Determined to stop the Alcidalisus and save her beloved homeland, Orion embarked on a perilous quest to find the ancient artifact known as the Fireblaze, which held the power to defeat the dark sorcerer once and for all.
# With her trusty wand in hand, and her unwavering courage and determination, Orion braved treacherous mountains, dark forests, and treacherous swamps, facing countless dangers and overcoming countless obstacles along the way.
# Finally, after many long and arduous days, Orion reached the heart of the Fireblaze, and with a mighty spell, she unleashed its power upon the land, banishing the Alcidalisus Grimbletone forever.
# And so, the land of Aloria was saved, thanks to the bravery and cunning of the wise and powerful sorceress, Orion Gonzoshine.
# Astoria Goodspell, Eirendor Mountains, The Enchanted Ruby->
# Astoria Goodspell, Eirendor Mountains, The Enchanted Ruby->In the mystical Eirendor Mountains, there lived a magical creature named Astoria Goodspell.
# Astoria was a beautiful, shimmering unicorn with a flowing mane of silver and a sparkling gemstone in her forehead. She possessed the power to control the elements and could cast spells with just a flick of her tail.
# One day, Astoria embarked on a quest to find the legendary Enchanted Ruby, hidden deep within the Eirendor Mountains. With her magical powers, she braved treacherous paths and overcame dangerous creatures to reach the Ruby.
# As she held the Ruby in her hooves, Astoria felt an immense surge of energy and magic flow through her body. With this newfound power, she could control the elements with even greater precision and cast spells that could change the fate of the entire land.
# With her newfound abilities, Astoria returned to her home in the Eirendor Mountains, where she continued to use her powers to protect and defend the land from harm. Her legend grew, and she became known as the greatest magical creature of all time, forever changing the course of history.
# Felicitas Pendragon, Unknown Atlantis Mountain Range, The Quest for the Wishing Oracle->

# %%
df.to_csv(csv_file_name)
